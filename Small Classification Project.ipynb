# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
from sklearn import feature_selection as fs
from sklearn import preprocessing
from scipy import signal

# %%
from pandas import ExcelFile

# %%
data = pd.read_excel('FeaturesValues.xlsx', header=1)
data.head()
# Out:
#   Unnamed: 0 max. Amplitude Right Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0      Label             10-12500   500-1000  1000-1500  7500-8000
# 1          0              16.3204    16.3204    7.39846    2.01277
# 2          0              59.2658    59.2658    4.58665    1.65016
# 3          0              22.1542    22.1542    11.3877    3.14866
# 4          1               17.317    15.3166     17.317    4.19054
#
#   Integral Right Unnamed: 6 Unnamed: 7 Unnamed: 8 max. Amplitude Left  ...  \
# 0       10-12500   500-1000  1000-1500  7500-8000            10-12500  ...
# 1        7.42302    3.72127    1.46043   0.875289             22.6196  ...
# 2        12.4527    8.51801     1.6767    0.58734             28.8541  ...
# 3        9.54954    4.72982    2.10357    1.10204              14.717  ...
# 4         9.9764    2.85192    3.43175     1.2164             19.9769  ...
#
#   Unnamed: 16 abs(Int.L-Int.R) Int.L+Int.R abs(Int.L-Int.R).1 Int.L+Int.R.1  \
# 0   7500-8000         10-12500    10-12500           500-1000      500-1000
# 1    0.789872         0.825667     15.6717           0.122235       7.56478
# 2    0.186056           1.1861     23.7192            1.59408       15.4419
# 3    0.490615          1.68445     17.4146            1.71407       7.74558
# 4     0.29208          1.72782      18.225           0.178184       5.88203
#
#   abs(Int.L-Int.R).2 Int.L+Int.R.2 abs(Int.L-Int.R).3 Int.L+Int.R.3  \
# 0          1000-1500     1000-1500          7500-8000     7500-8000
# 1           0.509929       3.43078           0.085417       1.66516
# 2           0.764726       4.11813           0.401284      0.773396
# 3           0.202009       4.40915           0.611429       1.59266
# 4           0.107414       6.97092           0.924322       1.50848
#
#   Unnamed: 25
# 0     PenType
# 1          M4
# 2          M4
# 3          M4
# 4          M4
#
# [5 rows x 26 columns]

# %%
xls = pd.ExcelFile('FeaturesValues.xlsx')
xls = xls.parse( skiprows=2, index_col=None, na_values=['NA'])
xls=xls.drop(xls.columns[len(xls.columns)-1],axis=1)
xls
# Out:
#      Label    10-12500   500-1000   1000-1500  7500-8000  10-12500.1  \
# 0        0   16.320440  16.320440    7.398460   2.012775    7.423021
# 1        0   59.265753  59.265753    4.586654   1.650161   12.452657
# 2        0   22.154235  22.154235   11.387735   3.148665    9.549542
# 3        1   17.316986  15.316602   17.316986   4.190537    9.976401
# 4        1   10.101065  10.101065    5.519555   1.979642    4.513550
# ..     ...         ...        ...         ...        ...         ...
# 345      0   31.214287  22.988793   31.214287   0.594067   18.033293
# 346      0  100.509582  17.386822  100.509582   0.756998   36.389360
# 347      0    0.497392   0.007656    0.001532   0.000001    0.046128
# 348      0    0.483138   0.005590    0.000590   0.000001    0.038228
# 349      0    0.190281   0.007018    0.001402   0.000001    0.030371
#
#      500-1000.1  1000-1500.1  7500-8000.1  10-12500.2  ...  1000-1500.3  \
# 0      3.721272     1.460425     0.875289   22.619635  ...     1.970354
# 1      8.518008     1.676704     0.587340   28.854146  ...     2.441430
# 2      4.729822     2.103572     1.102044   14.716988  ...     2.305581
# 3      2.851924     3.431755     1.216401   19.976927  ...     3.539169
# 4      1.869357     1.128628     0.480537   33.964781  ...     3.651327
# ..          ...          ...          ...         ...  ...          ...
# 345    4.346499     8.493928     0.218962   54.566976  ...     8.429369
# 346    5.652329    22.772308     0.267712  237.327176  ...    55.542846
# 347    0.001057     0.000173     0.000000    0.406391  ...     0.000116
# 348    0.000845     0.000114     0.000001    0.754672  ...     0.000124
#  ..           ...         ...         ...         ...         ...          ...
#  345     0.125704    0.847462   36.914048    0.642332    8.050667     0.064559
#  346     0.835562  117.574367  190.353087   27.471104   38.775761    32.770539
#  347     0.000000    0.007808    0.084447    0.000138    0.001976     0.000058
#  348     0.000000    0.009366    0.085823    0.000325    0.002015     0.000010
#  349     0.000000    0.019931    0.080673    0.000437    0.002039     0.000038
#
#       1000-1500.5  7500-8000.4  7500-8000.5
#  0       3.430779     0.085417     1.665161
#  1       4.118134     0.401284     0.773396
#  2       4.409152     0.611429     1.592659
#  3       6.970924     0.924322     1.508481
#  4       4.779955     0.150298     0.810776
#  ..           ...          ...          ...
#  345    16.923297     0.093259     0.344666
#  346    78.315154     0.567851     1.103274
#  347     0.000289     0.000000     0.000000
#  348     0.000238     0.000000     0.000001
#  349     0.000301     0.000000     0.000000
#
#  [350 rows x 24 columns], 0      0
#  1      0
#  2      0
#  3      1
#  4      1
#        ..
#  345    0
#  346    0
#  347    0
#  348    0
#  349    0
#  Name: Label, Length: 350, dtype: int64)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.20)

# %% [markdown]
# ### RBF

# %%
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
#X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2,random_state=442)
from sklearn.svm import SVC
#svclassifier = SVC(kernel='linear')
#svclassifier = SVC(kernel='poly', degree=3)
svclassifier = SVC(C=1,kernel='rbf',gamma='auto')
svclassifier.fit(X_train, y_train)
y_pred = svclassifier.predict(X_test)
from sklearn.metrics import classification_report, confusion_matrix
print("Accuracy=",accuracy_score(y_test, y_pred))
print("Confusion Matrix \n",confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# Accuracy= 0.45714285714285713
# Confusion Matrix
#  [[29  1]
#  [37  3]]
#               precision    recall  f1-score   support
#
#            0       0.44      0.97      0.60        30
#            1       0.75      0.07      0.14        40
#
#     accuracy                           0.46        70
#    macro avg       0.59      0.52      0.37        70
# weighted avg       0.62      0.46      0.34        70

# %% [markdown]
# ### Linear

# %%
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
#X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2,random_state=442)
from sklearn.svm import SVC
svclassifier = SVC(kernel='linear')
#svclassifier = SVC(kernel='poly', degree=3)
svclassifier.fit(X_train, y_train)
y_pred = svclassifier.predict(X_test)
from sklearn.metrics import classification_report, confusion_matrix
print("Accuracy=",accuracy_score(y_test, y_pred))
print("Confusion Matrix \n",confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# Accuracy= 0.4142857142857143
# Confusion Matrix
#  [[27  3]
#  [38  2]]
#               precision    recall  f1-score   support
#
#            0       0.42      0.90      0.57        30
#            1       0.40      0.05      0.09        40
#
#     accuracy                           0.41        70
#    macro avg       0.41      0.48      0.33        70
# weighted avg       0.41      0.41      0.29        70

# %% [markdown]
# ### polynomial 2 degree

# %%
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
#X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2,random_state=442)
from sklearn.svm import SVC

svclassifier = SVC(kernel='poly', degree=2)
svclassifier.fit(X_train, y_train)
y_pred = svclassifier.predict(X_test)
from sklearn.metrics import classification_report, confusion_matrix
print("Accuracy=",accuracy_score(y_test, y_pred))
print("Confusion Matrix \n",confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# C:\Users\Pc\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# Accuracy= 0.5428571428571428
# Confusion Matrix
#  [[16 14]
#  [18 22]]
#               precision    recall  f1-score   support
#
#            0       0.47      0.53      0.50        30
#            1       0.61      0.55      0.58        40
#
#     accuracy                           0.54        70
#    macro avg       0.54      0.54      0.54        70
# weighted avg       0.55      0.54      0.55        70

# %% [markdown]
# ### Knn classifier

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
k_range =range(1,26)
scores={}
scores_list=[]
for k in k_range:
    neigh = KNeighborsClassifier(n_neighbors=k)
    neigh.fit(X, Y)
    y_pred=neigh.predict(X_test)
print("Accuracy=",accuracy_score(y_test, y_pred))
print("Confusion Matrix \n",confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# Accuracy= 0.5714285714285714
# Confusion Matrix
#  [[14 16]
#  [14 26]]
#               precision    recall  f1-score   support
#
#            0       0.50      0.47      0.48        30
#            1       0.62      0.65      0.63        40
#
#     accuracy                           0.57        70
#    macro avg       0.56      0.56      0.56        70
# weighted avg       0.57      0.57      0.57        70
